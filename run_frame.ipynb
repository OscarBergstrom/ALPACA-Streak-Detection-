# %%
import sys
import os
print(os.path.exists(r"C:\Users\carlo\RMS"))
print(os.path.exists(r"C:\Users\carlo\RMS\RMS"))  # the inner RMS package folder
sys.path.append(r"C:\Users\carlo\RMS")
sys.path.append(r"C:\Users\carlo\Summer Project")    # the folder that CONTAINS PipelineCode
from PipelineCode.frame import OperatingFitsFiles

frame = OperatingFitsFiles("C:/Users/carlo/Summer Project/2026-06-15T23_01_47.560.fits", site="paranal", simulated=False)
frame.opening_fits_file()
frame.run_crop_procedure()
frame.undistort_fits()
frame.run_hough_transform()
# Out:
# True
# True
# SIMPLE  =                    T                                                  BITPIX  =                   16 /8 unsigned int, 16 & 32 int, -32 & -64 real     NAXIS   =                    2 /number of axes                                  NAXIS1  =                 8750 /fastest changing axis                           NAXIS2  =                 8750 /next to fastest changing axis                   BSCALE  =                    1 / physical = BZERO + BSCALE*array_value          BZERO   =                32768 / physical = BZERO + BSCALE*array_value          EXPTIME =   120.00000000000000 /Exposure time in seconds                        EXPOSURE=   120.00000000000000 /Exposure time in seconds                        CCD-TEMP= -0.14025878906250000 /CCD temperature at start of exposure in C       XPIXSZ  =   3.7599999999999998 /Pixel Width in microns (after binning)          YPIXSZ  =   3.7599999999999998 /Pixel Height in microns (after binning)         XBINNING=                    1 /Binning factor in width                         YBINNING=                    1 /Binning factor in height                        XORGSUBF=                    0 / Subframe X position in binned pixels           YORGSUBF=                    0 /Subframe Y position in binned pixels            READOUTM= '16 bit  ' /          Readout mode of image                           FILTER  = 'Luminance' /         Filter used when taking image                   EGAIN   =  0.77999997138977051 /Electronic gain in e-/ADU                       GAIN    =                    0                                                  FOCUSSSZ=   10.000000000000000 /Focuser step size in microns                    SITELAT = '00 00 00' /          Latitude of the imaging location                SITELONG= '00 00 00' /          Longitude of the imaging location               JD      =   2461207.4595782408 /Julian Date at time of exposure                 JD-HELIO=   2461207.4597089146 /Heliocentric Julian Date at time of exposure    OBJECT  = 'ALL SKY '                                                            TELESCOP= 'ALPACA  '           / telescope used to acquire this image           INSTRUME= 'ALPACA  '           / instrument or camera used                      OBSERVER= 'ESO Paranal Observatory'                                             ROWORDER= 'TOP-DOWN' /          Image write order, BOTTOM-UP or TOP-DOWN        DATE-OBS= '2026-06-15T23:01:47.560'                                             MJD-OBS =    61206.95957824074                                                  MJD-END =    61206.96096712963                                                  DATE-END= '2026-06-15T23:03:47.560'                                             RADESYS = 'ICRS    '                                                            CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            LONPOLE =                180.0                                                  CRPIX1  =                  0.0                                                  CRPIX2  =                  0.0                                                  CRVAL1  =                  0.0                                                  CRVAL2  =                  0.0                                                  CD1_1   =                  1.0                                                  CD1_2   =                  0.0                                                  CD2_1   =                  0.0                                                  CD2_2   =                  1.0                                                  TT1     = 'IMA/SERIES WINDOW'                                                   BIN1    =                    1                                                  BIN2    =                    1                                                  DATAMAX =              65535.0                                                   ...
# 2461207.4595782408
# 178.9441197554358 -24.47691123743238
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# The fit may be unsuccessful; check fit_info['message'] for more information.
# [3265.57698724] [3724.01615942]
# Platepar
# --------
# Camera info:
#     Lat (+N)  =  -24.627600 deg
#     Lon (+E)  =  -70.405098 deg
#     Ele (MSL) =     2648.00 m
#     FOV       = 190.60 x 190.56 deg
#     Img res   =   8750 x   8750 px
# Reference pointing - equatorial (J2000):
#     JD      = 2461207.5624236111
#     RA      =  217.785060 deg
#     Dec     =  -25.447082 deg
#     Pos ang = 359.951050 deg
#     Pix scl = 1.17 arcmin/px
# Reference pointing - apparent azimuthal (date):
#     Azim    = 120.783200 deg (+E of N)
#     Alt     = 88.152376 deg
#     Rot/hor = -0.477279 deg
# Distortion:
#     Type = radial7-odd
#     Distortion coeffs (radial):
#             x0 (px),  y0 (px),       a1, a2 (deg),       k1,       k2,       k3,       k4
# img2sky  =  -80.889,   +1.193,   -0.007, +197.126,   +0.102, +6.2e-04,   +0.005
# sky2img  =  -80.874,   +1.185,   -0.007, +196.706,   +0.101,   -0.025,   +0.006
# Photometry:
#     Slope     = -2.500
#     Zeropoint = 10.000 +/- nan
#     Gamma     =  1.000
#     Vignetting coeff =  0.000
#     Vignetting fixed = True
#     Extinction scale =  0.600
#
# Original size: 8750 x 8750
# Cropped size:  6491 x 6492
# Crop offset (add back before using the platepar again): X0=1104, Y0=1093
# Wrote cropped FITS: C:/Users/carlo/Summer Project/2026-06-15T23_01_47.560.fits_cropped67deg.fits
# Building dense analytic undistortion map: 6491 x 6492 pixels...
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# VerifyWarning: Card is too long, comment will be truncated.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:810, in _free_space_check(hdulist, dirname)
#     809 try:
# --> 810     yield
#     811 except OSError as exc:
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\base.py:722, in _BaseHDU._writeto(self, fileobj, inplace, copy)
#     721 with _free_space_check(self, dirname):
# --> 722     self._writeto_internal(fileobj, inplace, copy)
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\base.py:728, in _BaseHDU._writeto_internal(self, fileobj, inplace, copy)
#     727 header_offset, _ = self._writeheader(fileobj)
# --> 728 data_offset, data_size = self._writedata(fileobj)
#     730 # Set the various data location attributes on newly-written HDUs
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\base.py:659, in _BaseHDU._writedata(self, fileobj)
#     658 if self.data is not None:
# --> 659     size += self._writedata_internal(fileobj)
#     660 # pad the FITS data block
#     661 # to avoid a bug in the lustre filesystem client, don't
#     662 # write zero-byte objects
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\image.py:674, in _ImageBaseHDU._writedata_internal(self, fileobj)
#     673 try:
# --> 674     fileobj.writearray(output)
#     675 finally:
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\file.py:432, in _File.writearray(self, array)
#     431 if hasattr(self._file, "write"):
# --> 432     _array_to_file(array, self._file)
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:623, in _array_to_file(arr, outfile)
#     622 while idx < arr.nbytes:
# --> 623     write(arr[idx : idx + chunksize], outfile)
#     624     idx += chunksize
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:591, in _array_to_file.<locals>.<lambda>(a, f)
#     590 if isfile(outfile) and seekable:
# --> 591     write = lambda a, f: a.tofile(f)
#     592 else:
#
# OSError: 42139572 requested and 0 written
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:810, in _free_space_check(hdulist, dirname)
#     809 try:
# --> 810     yield
#     811 except OSError as exc:
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\hdulist.py:1043, in HDUList.writeto(self, fileobj, output_verify, overwrite, checksum)
#    1042 hdu._prewriteto(checksum=checksum)
# -> 1043 hdu._writeto(hdulist._file)
#    1044 hdu._postwriteto()
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\base.py:722, in _BaseHDU._writeto(self, fileobj, inplace, copy)
#     721 with _free_space_check(self, dirname):
# --> 722     self._writeto_internal(fileobj, inplace, copy)
#
# File ~\anaconda3\envs\summerproject\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:830, in _free_space_check(hdulist, dirname)
#     828     hdu._close()
# --> 830 raise OSError(error_message + str(exc))
#
# OSError: Not enough space on disk: requested 168558288, available 134209536. 42139572 requested and 0 written
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 12
#      10 frame.opening_fits_file()
#      11 frame.run_crop_procedure()
# ---> 12 frame.undistort_fits()
#      13 frame.run_hough_transform()
#
# File ~\Summer Project\PipelineCode\frame.py:301, in OperatingFitsFiles.undistort_fits(self)
#     300 def undistort_fits(self):
# --> 301     self.undistort_cropped_fits(
#     302         cropped_fits_path=f"{self.file_name}_cropped67deg.fits",
#     303         fits_out_path=f"{self.file_name}_undistorted.fits",
#     304     )
#
# File ~\Summer Project\PipelineCode\frame.py:296, in OperatingFitsFiles.undistort_cropped_fits(self, cropped_fits_path, fits_out_path, out_width, out_height)
#     292 header["UND_H"] = (out_height, "Undistorted image height used to build this map")
#     293 # CROP_X0/CROP_Y0 already present from the crop step -- keep them; they're
#     294 # still needed to map all the way back to the ORIGINAL uncropped frame.
# --> 296 fits.writeto(fits_out_path, corrected, header, overwrite=True)
#     297 print(f"Wrote undistorted FITS: {fits_out_path}")
#     298 return fits_out_path
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\convenience.py:464, in writeto(filename, data, header, output_verify, overwrite, checksum)
#     462 if hdu.is_image and not isinstance(hdu, PrimaryHDU):
#     463     hdu = PrimaryHDU(data, header=header)
# --> 464 hdu.writeto(
#     465     filename, overwrite=overwrite, output_verify=output_verify, checksum=checksum
#     466 )
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\base.py:412, in _BaseHDU.writeto(self, name, output_verify, overwrite, checksum)
#     409 from .hdulist import HDUList
#     411 hdulist = HDUList([self])
# --> 412 hdulist.writeto(name, output_verify, overwrite=overwrite, checksum=checksum)
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\hdu\hdulist.py:1044, in HDUList.writeto(self, fileobj, output_verify, overwrite, checksum)
#    1042             hdu._prewriteto(checksum=checksum)
#    1043             hdu._writeto(hdulist._file)
# -> 1044             hdu._postwriteto()
#    1045 finally:
#    1046     hdulist.close(output_verify=output_verify, closed=closed)
#
# File ~\anaconda3\envs\summerproject\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~\anaconda3\envs\summerproject\lib\site-packages\astropy\io\fits\util.py:830, in _free_space_check(hdulist, dirname)
#     827 for hdu in hdulist:
#     828     hdu._close()
# --> 830 raise OSError(error_message + str(exc))
#
# OSError: Not enough space on disk: requested 168558288, available 134209536. Not enough space on disk: requested 168558288, available 134209536. 42139572 requested and 0 written
